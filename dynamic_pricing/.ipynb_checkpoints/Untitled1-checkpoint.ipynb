# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
sns.set_theme("paper")

pd.read_csv('sales.csv')
# Out:
#        SKU  SKU.1   plan  0   1   2   3   4   5   6  ...    13     14     15  \
# 0    10060  10060  120.0  3   5   8  14  19  22  27  ...  56.0   61.0   68.0
# 1    10121  10121  150.0  7  11  17  21  30  33  38  ...  73.0   75.0   80.0
# 2    10216  10216   50.0  0   1   4   4   5   8   9  ...  20.0   22.0   22.0
# 3    10230  10230  150.0  5  12  18  23  27  34  43  ...  95.0  100.0  104.0
# 4    10388  10388  160.0  4   8  13  17  21  24  30  ...  57.0   60.0   64.0
# ..     ...    ...    ... ..  ..  ..  ..  ..  ..  ..  ...   ...    ...    ...
# 821  98842  98842   60.0  3   7   8   8   9  10  13  ...  21.0   21.0   24.0
# 822  99266  99266  150.0  5  12  17  24  31  36  41  ...  84.0   94.0  100.0
# 823  99310  99310   70.0  2   3   5   7   7   8   9  ...  21.0   22.0   24.0
# 824  99974  99974   30.0  0   1   1   2   4   6   7  ...  16.0   16.0   17.0
# 825  99996  99996  150.0  4   8  13  18  23  28  32  ...  85.0   88.0   96.0
#
# ...

# %%
sales = pd.read_csv('sales.csv')
(sales.iloc[:, -1]/sales['plan']).hist(bins=29)
# Out:
# <AxesSubplot: >

# %%
y = []
for d in range(3, 30):
    y.append(np.exp(d/10)/(1 - 1.6*np.exp(d/10)) + 1.62)
    
plt.plot(range(3, 30), y)

# %%
y
# Out:
# [0.4561019471415584,
#  0.5443610172126667,
#  0.6134264104106684,
#  0.6686957101729795,
#  0.7137224205585903,
#  0.7509418862422186,
#  0.7820792883624507,
#  0.808391109267138,
#  0.8308143164166191,
#  0.8500619467732147,
#  0.8666862899221044,
#  0.8811217993773925,
#  0.8937149358229808,
#  0.9047453619343915,
#  0.9144412790152259,
#  0.9229907122881998,
#  0.9305499417255814,
#  0.9372498875989875,
#  0.9432010079962517,
#  0.9484970985431971,
#  0.9532182718234543,
#  0.9574333166027815,
#  0.9612015830310482,
#  0.9645745018758811,
#  0.96759681854844,
#  0.9703076029033922,
#  0.9727410813018758]

# %%
28/29
# Out:
# 0.9655172413793104

# %%
{
  "@timestamp": [
    "2023-06-05T06:57:28.072Z"
  ],
  "kubernetes.annotations.kubectl_kubernetes_io/restartedAt": [
    "2023-01-31T12:48:28.000Z"
  ],
  "kubernetes.annotations.kubernetes_io/psp": [
    "eks.privileged"
  ],
  "kubernetes.annotations.kubernetes_io/psp.keyword": [
    "eks.privileged"
  ],
  "kubernetes.annotations.policies_kyverno_io/last-applied-patches": [
    "add-default-nodeselector.mutating-add-default-nodeselector.kyverno.io: added /spec/nodeSelector\n"
  ],
  "kubernetes.annotations.policies_kyverno_io/last-applied-patches.keyword": [
    "add-default-nodeselector.mutating-add-default-nodeselector.kyverno.io: added /spec/nodeSelector\n"
  ],
  "kubernetes.container_hash": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp@sha256:c5cb58866e3a5d49838cff4f3063463120d4e2fbd2e9b9b0889bed31a4e4314b"
  ],
  "kubernetes.container_hash.keyword": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp@sha256:c5cb58866e3a5d49838cff4f3063463120d4e2fbd2e9b9b0889bed31a4e4314b"
  ],
  "kubernetes.container_image": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp:master_b12"
  ],
  "kubernetes.container_image.keyword": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp:master_b12"
  ],
  "kubernetes.container_name": [
    "ihs-shiny"
  ],
  "kubernetes.container_name.keyword": [
    "ihs-shiny"
  ],
  "kubernetes.docker_id": [
    "56d6633cf08b66cded69561311d5bf0c30dd7f88fe238c1c4c46bd83fbfb22da"
  ],
  "kubernetes.docker_id.keyword": [
    "56d6633cf08b66cded69561311d5bf0c30dd7f88fe238c1c4c46bd83fbfb22da"
  ],
  "kubernetes.host": [
    "ip-10-194-178-187.eu-central-1.compute.internal"
  ],
  "kubernetes.host.keyword": [
    "ip-10-194-178-187.eu-central-1.compute.internal"
  ],
  "kubernetes.labels.app": [
    "ihs-shiny"
  ],
  "kubernetes.labels.app.keyword": [
    "ihs-shiny"
  ],
  "kubernetes.labels.pod-template-hash": [
    "5c69499594"
  ],
  "kubernetes.labels.pod-template-hash.keyword": [
    "5c69499594"
  ],
  "kubernetes.namespace_name": [
    "ihs-lvpf-dev"
  ],
  "kubernetes.namespace_name.keyword": [
    "ihs-lvpf-dev"
  ],
  "kubernetes.pod_id": [
    "be8b9098-eac9-4458-a63e-b1b3fd076f0d"
  ],
  "kubernetes.pod_id.keyword": [
    "be8b9098-eac9-4458-a63e-b1b3fd076f0d"
  ],
  "kubernetes.pod_name": [
    "ihs-shiny-5c69499594-fdv84"
  ],
  "kubernetes.pod_name.keyword": [
    "ihs-shiny-5c69499594-fdv84"
  ],
  "log": [
    "2023-06-05T06:57:28.072024099Z stderr F S3 Connection still valid"
  ],
  "log.keyword": [
    "2023-06-05T06:57:28.072024099Z stderr F S3 Connection still valid"
  ],
  "_id": "cNVYiogBcxnTGoj_si-O",
  "_index": "tire_data_science_factory-000003",
  "_score": null
}

# %%
{
  "@timestamp": [
    "2023-06-05T06:57:52.269Z"
  ],
  "kubernetes.annotations.kubectl_kubernetes_io/restartedAt": [
    "2023-01-31T12:48:28.000Z"
  ],
  "kubernetes.annotations.kubernetes_io/psp": [
    "eks.privileged"
  ],
  "kubernetes.annotations.kubernetes_io/psp.keyword": [
    "eks.privileged"
  ],
  "kubernetes.annotations.policies_kyverno_io/last-applied-patches": [
    "add-default-nodeselector.mutating-add-default-nodeselector.kyverno.io: added /spec/nodeSelector\n"
  ],
  "kubernetes.annotations.policies_kyverno_io/last-applied-patches.keyword": [
    "add-default-nodeselector.mutating-add-default-nodeselector.kyverno.io: added /spec/nodeSelector\n"
  ],
  "kubernetes.container_hash": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp@sha256:c5cb58866e3a5d49838cff4f3063463120d4e2fbd2e9b9b0889bed31a4e4314b"
  ],
  "kubernetes.container_hash.keyword": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp@sha256:c5cb58866e3a5d49838cff4f3063463120d4e2fbd2e9b9b0889bed31a4e4314b"
  ],
  "kubernetes.container_image": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp:master_b12"
  ],
  "kubernetes.container_image.keyword": [
    "682562199936.dkr.ecr.eu-central-1.amazonaws.com/tires/shinyapp:master_b12"
  ],
  "kubernetes.container_name": [
    "ihs-shiny"
  ],
  "kubernetes.container_name.keyword": [
    "ihs-shiny"
  ],
  "kubernetes.docker_id": [
    "56d6633cf08b66cded69561311d5bf0c30dd7f88fe238c1c4c46bd83fbfb22da"
  ],
  "kubernetes.docker_id.keyword": [
    "56d6633cf08b66cded69561311d5bf0c30dd7f88fe238c1c4c46bd83fbfb22da"
  ],
  "kubernetes.host": [
    "ip-10-194-178-187.eu-central-1.compute.internal"
  ],
  "kubernetes.host.keyword": [
    "ip-10-194-178-187.eu-central-1.compute.internal"
  ],
  "kubernetes.labels.app": [
    "ihs-shiny"
  ],
  "kubernetes.labels.app.keyword": [
    "ihs-shiny"
  ],
  "kubernetes.labels.pod-template-hash": [
    "5c69499594"
  ],
  "kubernetes.labels.pod-template-hash.keyword": [
    "5c69499594"
  ],
  "kubernetes.namespace_name": [
    "ihs-lvpf-dev"
  ],
  "kubernetes.namespace_name.keyword": [
    "ihs-lvpf-dev"
  ],
  "kubernetes.pod_id": [
    "be8b9098-eac9-4458-a63e-b1b3fd076f0d"
  ],
  "kubernetes.pod_id.keyword": [
    "be8b9098-eac9-4458-a63e-b1b3fd076f0d"
  ],
  "kubernetes.pod_name": [
    "ihs-shiny-5c69499594-fdv84"
  ],
  "kubernetes.pod_name.keyword": [
    "ihs-shiny-5c69499594-fdv84"
  ],
  "log": [
    "2023-06-05T06:57:52.269485665Z stderr F   1: shiny::runApp"
  ],
  "log.keyword": [
    "2023-06-05T06:57:52.269485665Z stderr F   1: shiny::runApp"
  ],
  "_id": "0tZZiogBcxnTGoj_ELg6",
  "_index": "tire_data_science_factory-000003",
  "_score": null
}
